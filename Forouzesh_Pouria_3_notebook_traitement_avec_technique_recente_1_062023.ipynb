# %%
# !pip install --upgrade pip

# %%
# !pip install fastparquet

# %%
# !pip install pathvalidate

# %%
# !pip install plot_keras_history

# %%
import pandas as pd
import numpy as np

import tensorflow as tf
import os
import shutil
from pathvalidate import sanitize_filename
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

from plot_keras_history import show_history, plot_history

import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
batch_size = 32

# %% [markdown]
# # Préparation des données

# %% [markdown]
# On commence par préparer le dossier d'images. En effet, toutes les images sont mélangées dans le même dossier, or la fonction que nous allons utiliser
# tf.keras.utils.image_dataset_from_directory s'attend à un sous-répertoire par catégorie

# %%
df = pd.read_csv("df_clean.csv")

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  55b85ea15a1536d46b7190ad6fff8ce7  2016-04-30 03:22:56 +0000
# 1  7b72c92c2f6c40268628ec5f14c6d590  2016-04-30 03:22:56 +0000
# 2  64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 3  d4684dcdc759dd9cdf41504698d737d8  2016-06-20 08:49:52 +0000
# 4  6325b6870c54cd47be6ebfbffa620ec7  2016-06-20 08:49:52 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/elegance-polyester-mul...
# 1  http://www.flipkart.com/sathiyas-cotton-bath-t...
# 2  http://www.flipkart.com/eurospa-cotton-terry-f...
# 3  http://www.flipkart.com/santosh-royal-fashion-...
# 4  http://www.flipkart.com/jaipur-print-cotton-fl...
#
#                                         product_name  \
# 0  Elegance Polyester Multicolor Abstract Eyelet ...
# 1                         Sathiyas Cotton Bath Towel
# 2                Eurospa Cotton Terry Face Towel Set
# 3  SANTOSH ROYAL FASHION Cotton Printed King size...
# 4  Jaipur Print Cotton Floral King sized Double B...
#
#                                product_category_tree               pid  \
# 0  ["Home Furnishing >> Curtains & Accessories >>...  CRNEG7BKMFFYHQ8Z
# 1  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEGFZHGBXPHZUH
# 2  ["Baby Care >> Baby Bath & Skin >> Baby Bath T...  BTWEG6SHXTDB2A2Y
# 3  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJT9UQWHDUBH4
# 4  ["Home Furnishing >> Bed Linen >> Bedsheets >>...  BDSEJTHNGWVGWWQU
#
#    retail_price  discounted_price                                 image  \
# 0        1899.0             899.0  55b85ea15a1536d46b7190ad6fff8ce7.jpg
# 1         600.0             449.0  7b72c92c2f6c40268628ec5f14c6d590.jpg
# 2           NaN               NaN  64d5d4a258243731dc7bbb1eef49ad74.jpg
# 3        2699.0            1299.0  d4684dcdc759dd9cdf41504698d737d8.jpg
# 4        2599.0             698.0  6325b6870c54cd47be6ebfbffa620ec7.jpg
#
#    is_FK_Advantage_product                                        description  \
# 0                    False  Key Features of Elegance Polyester Multicolor ...
# 1                    False  Specifications of Sathiyas Cotton Bath Towel (...
# 2                    False  Key Features of Eurospa Cotton Terry Face Towe...
# 3                    False  Key Features of SANTOSH ROYAL FASHION Cotton P...
# 4                    False  Key Features of Jaipur Print Cotton Floral Kin...
#
#         product_rating       overall_rating                  brand  \
# 0  No rating available  No rating available               Elegance
# 1  No rating available  No rating available               Sathiyas
# 2  No rating available  No rating available                Eurospa
# 3  No rating available  No rating available  SANTOSH ROYAL FASHION
# 4  No rating available  No rating available           Jaipur Print
#
#                               product_specifications        category0  \
# 0  {"product_specification"=>[{"key"=>"Brand", "v...  home furnishing
# 1  {"product_specification"=>[{"key"=>"Machine Wa...        baby care
# 2  {"product_specification"=>[{"key"=>"Material",...        baby care
# 3  {"product_specification"=>[{"key"=>"Brand", "v...  home furnishing
# 4  {"product_specification"=>[{"key"=>"Machine Wa...  home furnishing
#
#                               cleaned_product_name  \
# 0  polyest multicolor abstract eyelet door curtain
# 1                                cotton bath towel
# 2                          cotton terri face towel
# 3                       cotton king doubl bedsheet
# 4                cotton floral king doubl bedsheet
#
#                                  cleaned_description
# 0  polyest multicolor abstract eyelet door curtai...
# 1  cotton bath towel bath towel yellow blue bath ...
# 2  cotton terri face towel small cotton terri fac...
# 3  cotton king doubl bedsheet royal bedsheet perf...
# 4  cotton floral king doubl bedsheet cotton cotto...

# %%
def dataset_fct(path, validation_split=0, data_type=None) :
    dataset = tf.keras.utils.image_dataset_from_directory(
        path, labels='inferred', label_mode='categorical',
        class_names=None, batch_size=batch_size, image_size=(224,224), shuffle=True,
        validation_split=validation_split, subset=data_type, seed=42
    )
    return dataset

# %%
path2 = "C:/Users/pouri/OneDrive/Bureau/P6/7categ1/train"
path3 = "C:/Users/pouri/OneDrive/Bureau/P6/7categ1/test"

# %%
dataset_train = dataset_fct(path2, validation_split=0.25, data_type='training')
dataset_val = dataset_fct(path2, validation_split=0.25, data_type='validation')
dataset_test = dataset_fct(path3, validation_split=0, data_type=None)
# Out:
# Found 892 files belonging to 7 classes.
# Using 669 files for training.
# Found 892 files belonging to 7 classes.
# Using 223 files for validation.
# Found 158 files belonging to 7 classes.

# %% [markdown]
# # Création du modèle

# %%
def create_model() :
    # Data augmentation : les fonctions de data augmentations ne sont actives que durant les fit
    data_augmentation = tf.keras.models.Sequential([
        tf.keras.layers.RandomFlip("horizontal", input_shape=(224, 224, 3)),
        tf.keras.layers.RandomRotation(0.1),
        tf.keras.layers.RandomZoom(0.1),
      ])
    
    # Récupération modèle pré-entraîné
    model_base = tf.keras.applications.vgg19.VGG19(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
    for layer in model_base.layers:
        layer.trainable = False

    # Définition du nouveau modèle
    model = tf.keras.models.Sequential([
        data_augmentation,
        tf.keras.layers.Lambda(tf.keras.applications.vgg19.preprocess_input, input_shape=(224, 224, 3)),
        tf.keras.layers.Rescaling(1./127.5, offset=-1),
        model_base,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(7, activation='softmax')
    ])

    # compilation du modèle 
    model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=["accuracy"])

    return model

# %%
model = create_model()
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
model_save_path = "./model_best_weights_vgg19.h5"
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(model_save_path, monitor="val_loss", verbose=1, save_best_only=True, mode="min")
earlystopping_cb = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=10)

# %% [markdown]
# # Entrainement

# %%
t0 = time.time()
history = model.fit(dataset_train,
          validation_data=dataset_val,
          batch_size=32, epochs=100, callbacks=[checkpoint_cb, earlystopping_cb], verbose=1)
print(f"Durée de l'entrainement: {time.time() - t0}")
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 21/21 [==============================] - ETA: 0s - loss: 1.8734 - accuracy: 0.2750
# Epoch 1: val_loss improved from inf to 1.45869, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 93s 4s/step - loss: 1.8734 - accuracy: 0.2750 - val_loss: 1.4587 - val_accuracy: 0.5830
# Epoch 2/100
# 21/21 [==============================] - ETA: 0s - loss: 1.4160 - accuracy: 0.5097
# Epoch 2: val_loss improved from 1.45869 to 1.16534, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 90s 4s/step - loss: 1.4160 - accuracy: 0.5097 - val_loss: 1.1653 - val_accuracy: 0.6592
# Epoch 3/100
# 21/21 [==============================] - ETA: 0s - loss: 1.1236 - accuracy: 0.6442
# Epoch 3: val_loss improved from 1.16534 to 1.03330, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 91s 4s/step - loss: 1.1236 - accuracy: 0.6442 - val_loss: 1.0333 - val_accuracy: 0.6682
# Epoch 4/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9886 - accuracy: 0.6861
# Epoch 4: val_loss improved from 1.03330 to 0.93979, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 91s 4s/step - loss: 0.9886 - accuracy: 0.6861 - val_loss: 0.9398 - val_accuracy: 0.6951
# Epoch 5/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9113 - accuracy: 0.7250
# Epoch 5: val_loss improved from 0.93979 to 0.89807, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 90s 4s/step - loss: 0.9113 - accuracy: 0.7250 - val_loss: 0.8981 - val_accuracy: 0.7175
# Epoch 6/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8447 - accuracy: 0.7265
# Epoch 6: val_loss did not improve from 0.89807
# 21/21 [==============================] - 90s 4s/step - loss: 0.8447 - accuracy: 0.7265 - val_loss: 0.9097 - val_accuracy: 0.7175
# Epoch 7/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8015 - accuracy: 0.7444
# Epoch 7: val_loss improved from 0.89807 to 0.84264, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 96s 5s/step - loss: 0.8015 - accuracy: 0.7444 - val_loss: 0.8426 - val_accuracy: 0.7354
# Epoch 8/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7742 - accuracy: 0.7504
# Epoch 8: val_loss improved from 0.84264 to 0.83936, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 93s 4s/step - loss: 0.7742 - accuracy: 0.7504 - val_loss: 0.8394 - val_accuracy: 0.7309
# Epoch 9/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7230 - accuracy: 0.7773
# Epoch 9: val_loss did not improve from 0.83936
# 21/21 [==============================] - 93s 4s/step - loss: 0.7230 - accuracy: 0.7773 - val_loss: 0.8550 - val_accuracy: 0.7309
# Epoch 10/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.7534
# Epoch 10: val_loss improved from 0.83936 to 0.81877, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 91s 4s/step - loss: 0.7398 - accuracy: 0.7534 - val_loss: 0.8188 - val_accuracy: 0.7758
# Epoch 11/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6653 - accuracy: 0.8072
# Epoch 11: val_loss did not improve from 0.81877
# 21/21 [==============================] - 92s 4s/step - loss: 0.6653 - accuracy: 0.8072 - val_loss: 0.8225 - val_accuracy: 0.7309
# Epoch 12/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6556 - accuracy: 0.7877
# Epoch 12: val_loss did not improve from 0.81877
# 21/21 [==============================] - 92s 4s/step - loss: 0.6556 - accuracy: 0.7877 - val_loss: 0.8223 - val_accuracy: 0.7354
# Epoch 13/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6567 - accuracy: 0.7922
# Epoch 13: val_loss did not improve from 0.81877
# 21/21 [==============================] - 92s 4s/step - loss: 0.6567 - accuracy: 0.7922 - val_loss: 0.8399 - val_accuracy: 0.7354
# Epoch 14/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6343 - accuracy: 0.8132
# Epoch 14: val_loss improved from 0.81877 to 0.81010, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 92s 4s/step - loss: 0.6343 - accuracy: 0.8132 - val_loss: 0.8101 - val_accuracy: 0.7309
# Epoch 15/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5946 - accuracy: 0.8072
# Epoch 15: val_loss improved from 0.81010 to 0.78136, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 92s 4s/step - loss: 0.5946 - accuracy: 0.8072 - val_loss: 0.7814 - val_accuracy: 0.7623
# Epoch 16/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5656 - accuracy: 0.8206
# Epoch 16: val_loss did not improve from 0.78136
# 21/21 [==============================] - 92s 4s/step - loss: 0.5656 - accuracy: 0.8206 - val_loss: 0.7889 - val_accuracy: 0.7534
# Epoch 17/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5497 - accuracy: 0.8176
# Epoch 17: val_loss did not improve from 0.78136
# 21/21 [==============================] - 92s 4s/step - loss: 0.5497 - accuracy: 0.8176 - val_loss: 0.7986 - val_accuracy: 0.7534
# Epoch 18/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5458 - accuracy: 0.8236
# Epoch 18: val_loss did not improve from 0.78136
# 21/21 [==============================] - 90s 4s/step - loss: 0.5458 - accuracy: 0.8236 - val_loss: 0.7999 - val_accuracy: 0.7489
# Epoch 19/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5360 - accuracy: 0.8311
# Epoch 19: val_loss did not improve from 0.78136
# 21/21 [==============================] - 91s 4s/step - loss: 0.5360 - accuracy: 0.8311 - val_loss: 0.7820 - val_accuracy: 0.7489
# Epoch 20/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5233 - accuracy: 0.8341
# Epoch 20: val_loss did not improve from 0.78136
# 21/21 [==============================] - 91s 4s/step - loss: 0.5233 - accuracy: 0.8341 - val_loss: 0.7834 - val_accuracy: 0.7758
# Epoch 21/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4855 - accuracy: 0.8520
# Epoch 21: val_loss improved from 0.78136 to 0.77986, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 91s 4s/step - loss: 0.4855 - accuracy: 0.8520 - val_loss: 0.7799 - val_accuracy: 0.7534
# Epoch 22/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.8416
# Epoch 22: val_loss did not improve from 0.77986
# 21/21 [==============================] - 91s 4s/step - loss: 0.4986 - accuracy: 0.8416 - val_loss: 0.7816 - val_accuracy: 0.7578
# Epoch 23/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4561 - accuracy: 0.8520
# Epoch 23: val_loss improved from 0.77986 to 0.77350, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 91s 4s/step - loss: 0.4561 - accuracy: 0.8520 - val_loss: 0.7735 - val_accuracy: 0.7668
# Epoch 24/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4467 - accuracy: 0.8580
# Epoch 24: val_loss did not improve from 0.77350
# 21/21 [==============================] - 93s 4s/step - loss: 0.4467 - accuracy: 0.8580 - val_loss: 0.8232 - val_accuracy: 0.7713
# Epoch 25/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.8520
# Epoch 25: val_loss improved from 0.77350 to 0.77314, saving model to .\model_best_weights_vgg19.h5
# 21/21 [==============================] - 93s 4s/step - loss: 0.4659 - accuracy: 0.8520 - val_loss: 0.7731 - val_accuracy: 0.7623
# Epoch 26/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4331 - accuracy: 0.8535
# Epoch 26: val_loss did not improve from 0.77314
# 21/21 [==============================] - 94s 4s/step - loss: 0.4331 - accuracy: 0.8535 - val_loss: 0.7855 - val_accuracy: 0.7668
# Epoch 27/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4263 - accuracy: 0.8670
# Epoch 27: val_loss did not improve from 0.77314
# 21/21 [==============================] - 90s 4s/step - loss: 0.4263 - accuracy: 0.8670 - val_loss: 0.7922 - val_accuracy: 0.7668
# Epoch 28/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4114 - accuracy: 0.8759
# Epoch 28: val_loss did not improve from 0.77314
# 21/21 [==============================] - 91s 4s/step - loss: 0.4114 - accuracy: 0.8759 - val_loss: 0.7944 - val_accuracy: 0.7578
# Epoch 29/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4152 - accuracy: 0.8774
# Epoch 29: val_loss did not improve from 0.77314
# 21/21 [==============================] - 92s 4s/step - loss: 0.4152 - accuracy: 0.8774 - val_loss: 0.8005 - val_accuracy: 0.7713
# Epoch 30/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4079 - accuracy: 0.8789
# Epoch 30: val_loss did not improve from 0.77314
# 21/21 [==============================] - 91s 4s/step - loss: 0.4079 - accuracy: 0.8789 - val_loss: 0.8161 - val_accuracy: 0.7758
# Epoch 31/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8804
# Epoch 31: val_loss did not improve from 0.77314
# 21/21 [==============================] - 91s 4s/step - loss: 0.3752 - accuracy: 0.8804 - val_loss: 0.7974 - val_accuracy: 0.7892
# Epoch 32/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3862 - accuracy: 0.8879
# Epoch 32: val_loss did not improve from 0.77314
# 21/21 [==============================] - 92s 4s/step - loss: 0.3862 - accuracy: 0.8879 - val_loss: 0.8331 - val_accuracy: 0.7578
# Epoch 33/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3579 - accuracy: 0.8864
# Epoch 33: val_loss did not improve from 0.77314
# 21/21 [==============================] - 91s 4s/step - loss: 0.3579 - accuracy: 0.8864 - val_loss: 0.7927 - val_accuracy: 0.7713
# Epoch 34/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3504 - accuracy: 0.8969
# Epoch 34: val_loss did not improve from 0.77314
# 21/21 [==============================] - 91s 4s/step - loss: 0.3504 - accuracy: 0.8969 - val_loss: 0.7942 - val_accuracy: 0.7848
# Epoch 35/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.8939
# Epoch 35: val_loss did not improve from 0.77314
# 21/21 [==============================] - 91s 4s/step - loss: 0.3409 - accuracy: 0.8939 - val_loss: 0.8303 - val_accuracy: 0.7623
# Epoch 35: early stopping
# Durée de l'entrainement: 3207.107642889023

# %% [markdown]
# # Evaluation

# %%
loss, accuracy = model.evaluate(dataset_train, verbose=True)
print("Training Accuracy   : {:.4f}".format(accuracy))
print()
loss, accuracy = model.evaluate(dataset_val, verbose=True)
print("Validation Accuracy :  {:.4f}".format(accuracy))
# Out:
# 21/21 [==============================] - 68s 3s/step - loss: 0.2479 - accuracy: 0.9118
# Training Accuracy   : 0.9118
#
# 7/7 [==============================] - 23s 3s/step - loss: 0.8303 - accuracy: 0.7623
# Validation Accuracy :  0.7623

# %%
# Score de l'epoch optimal

model.load_weights(model_save_path)

loss, accuracy = model.evaluate(dataset_val, verbose=False)
print("Validation Accuracy :  {:.4f}".format(accuracy))
print("Validation Loss     :  {:.4f}".format(loss))
# Out:
# Validation Accuracy :  0.7623
# Validation Loss     :  0.7731

# %%
show_history(history)
plot_history(history, path="standard.png")
plt.close()

# %% [markdown]
# Calculons sur l'ensemble de test

# %%
loss, accuracy = model.evaluate(dataset_test, verbose=False)
print("Test Accuracy       :  {:.4f}".format(accuracy))
print("Test Loss           :  {:.4f}".format(loss))
# Out:
# Test Accuracy       :  0.7595
# Test Loss           :  0.7165

# %% [markdown]
# # Conclusion

# %%
df['category0'].unique()
# Out:
# array(['home furnishing', 'baby care', 'watches',
#        'home decor & festive needs', 'kitchen & dining',
#        'beauty and personal care', 'computers'], dtype=object)

# %%
path3
# Out:
# 'C:/Users/pouri/OneDrive/Bureau/P6/7categ1/test'

# %%
files = os.listdir(path3)
files
# Out:
# ['baby care',
#  'beauty and personal care',
#  'computers',
#  'home decor & festive needs',
#  'home furnishing',
#  'kitchen & dining',
#  'watches']

# %%
files = os.listdir(path3 + '/Computers')
files
# Out:
# ['00e966a5049a262cfc72e6bbf68b80e7.jpg',
#  '26989e846c2096a5b59b59cbea2cc7ab.jpg',
#  '28e3f1e490cfc4b47bfb50671ff93283.jpg',
#  '291d5ff1e50dac3058cf10578f692085.jpg',
#  '41dccf212ff447cd7213a2b1e669e406.jpg',
#  '54754ccd18f2a75c53de68806176392a.jpg',
#  '568f331e1039bf2e0635b899c2b3248f.jpg',
#  '5a54c78b52c984e56500809e5bc27ae1.jpg',
#  '6057d1b6682ab473a3fe2ca8b4577259.jpg',
#  '6c3768639e82ceaeab681e083b897672.jpg',
#  '7e6ae1b372e8e0b509b83ba3658b8107.jpg',
#  '8e961e4fd248c9496ca54808d2d2b25f.jpg',
#  '964648862f322b2cc153239af04b22ef.jpg',
#  '9f141b3c3d9096f5a897d01b48e3b360.jpg',
#  '9fb8662af03c957ade34d4c816d4e903.jpg',
#  'a41371b2f8859b015031f0d5eda5184c.jpg',
#  'a76bf8400b3dbcdbe5a5678f4a8ea0f6.jpg',
#  'e426290a8f57e82680275bb91df91ad1.jpg',
#  'e86daf9ebcdfc5c5dd088cdb7f8f8db6.jpg',
#  'e8ee7868b0c3d1d04b482cd4f3ec5ccc.jpg',
#  'ea199e645da893f2ab0c45cf07face13.jpg',
#  'eeecf5d16fa6591290706f1fd0c6fc6e.jpg',
#  'fc009e0b404034e5ea065ba980917f33.jpg']

# %%
df_test_com = df[df['image'].isin(files)]
df_test_com.head(1)
# Out:
#                              uniq_id            crawl_timestamp  \
# 54  7e6ae1b372e8e0b509b83ba3658b8107  2016-06-17 11:45:06 +0000
#
#                                           product_url  \
# 54  http://www.flipkart.com/jrb-1033-smallest-mobi...
#
#                                          product_name  \
# 54  JRB 1033 Smallest Mobile Powered By OTG Enable...
#
#                                 product_category_tree               pid  \
# 54  ["Computers >> Laptop Accessories >> USB Gadge...  USGEJPQHFM7CVCYH
#
#     retail_price  discounted_price                                 image  \
# 54         499.0             249.0  7e6ae1b372e8e0b509b83ba3658b8107.jpg
#
#     is_FK_Advantage_product  \
# 54                    False
#
#                                           description       product_rating  \
# 54  Key Features of JRB 1033 Smallest Mobile Power...  No rating available
#
#          overall_rating brand          product_specifications  category0  \
# 54  No rating available   JRB  {"product_specification"=>nil}  computers
#
#                                  cleaned_product_name  \
# 54  smallest mobil power enabl android smart phone...
#
#                                   cleaned_description
# 54  smallest mobil power enabl android smart phone...

# %%
my_image = tf.keras.preprocessing.image.load_img(path3 +'/computers/26989e846c2096a5b59b59cbea2cc7ab.jpg', target_size=(224, 224))
my_image = tf.keras.preprocessing.image.img_to_array(my_image)
print(my_image.shape)
my_image = my_image.reshape((1, my_image.shape[0], my_image.shape[1], my_image.shape[2]))
prediction = model.predict(my_image)
# Out:
# (224, 224, 3)
# 1/1 [==============================] - 1s 708ms/step

# %%
dataset_test.class_names[prediction.argmax(axis=-1)[0]]
# Out:
# 'computers'

# %%
all_test_files = os.listdir('C:/Users/pouri/OneDrive/Bureau/P6/7categ1/test2')
all_test_files
# Out:
# ['009099b1f6e1e8f893ec29a7023153c4.jpg',
#  '00cbbc837d340fa163d11e169fbdb952.jpg',
#  '00e966a5049a262cfc72e6bbf68b80e7.jpg',
#  '020d2daba55a723128e4e07c0b0393a9.jpg',
#  '093097cfe5626f4ad8914e0a16a940b5.jpg',
#  '0abfcbe0e17dd50c4cf5fb1d6037d514.jpg',
#  '0c70a580d96e50966130e2885d8c3505.jpg',
#  '0d3e1dc0d38be59e9927e47f152e48aa.jpg',
#  '0dc4d2767fe8424a3263ab141884f83d.jpg',
#  '112a8a56ee40ee31ea06fb7ff23b5c25.jpg',
#  '142994b421c052a6193052c6c8c3d076.jpg',
#  '14bc693d9b86c58696e5917045e9d4de.jpg',
#  '1738ddb8f47f11ff0cb96fe6cad302c2.jpg',
#  '184ecf07ca4e2872eaf53d2344a1e783.jpg',
#  '1971dcd2f3058a4c87bdd7d87d4baeba.jpg',
#  '2110699b945ae766c8b8112038ac58b9.jpg',
#  '219b24362655097cb41bf06a0be8ee79.jpg',
#  '24e85c590481a7cedfe66597f253f2b2.jpg',
#  '26269fd0df12630eec4508c2cf3c94e1.jpg',
#  '26989e846c2096a5b59b59cbea2cc7ab.jpg',
#  '27b7851ae3dfc2ae8c1958cebe93bf0b.jpg',
#  '28e3f1e490cfc4b47bfb50671ff93283.jpg',
#  '291d5ff1e50dac3058cf10578f692085.jpg',
#  '29b1ca231e10d5269516b80bf9d0dffc.jpg',
#  '2abb35d6affd2796e664349a747bd302.jpg',
#  '2bf0ca6d25501c067cd12a2a4939443f.jpg',
#  '2cbad7ead8eb8dd92823b9f525c87b9c.jpg',
#  '2e474c49a7dfe704c35cf3990740daa3.jpg',
#  '2e8df36b35d22cf219cf8bae6c2af752.jpg',
#  '2f756aa2ceb1efda609c428a47308758.jpg',
#  '31ac1b66cc6bb396c83f124317589f8c.jpg',
#  '3589e80e8f7f3f3a5b65447389b90c2e.jpg',
#  '3830dda3491cd5b28ed42ae544bc44f0.jpg',
#  '387ecd9ec173d61b6dc5ceddc079b150.jpg',
#  '3a7b224bf1bc9cee9052f9c9df0355f6.jpg',
#  '3c4604dba348a99a2dfbbc2cd3928101.jpg',
#  '3c4ca34c50a5437a1bcc42b72fc1351f.jpg',
#  '3c74db45cbfc14a78b8466dca494b3bb.jpg',
#  '412d0425bb7076610aace6549ded265c.jpg',
#  '41384da51732c0b4df3de8f395714fbb.jpg',
#  '41ae5a7304f3dc1dc8bc2dfc7765ae4d.jpg',
#  '41dccf212ff447cd7213a2b1e669e406.jpg',
#  '456ec612b30d4b091639843cdb66bf54.jpg',
#  '4589c5021b21525b4779260f7e86f355.jpg',
#  '4e09d5a71d46d61de3d4c9c5aedb73f2.jpg',
#  '4f6006b716c6546033fbaf9ff32de577.jpg',
#  '54754ccd18f2a75c53de68806176392a.jpg',
#  '568f331e1039bf2e0635b899c2b3248f.jpg',
#  '5749bae8ccead7997ebf370b6b081d07.jpg',
#  '57578c1e6ec61a880a6f3f971f5f77b8.jpg',
#  '597a9549a3e397d52dca62ee47b1f60a.jpg',
#  '5a54c78b52c984e56500809e5bc27ae1.jpg',
#  '5ae4626271e8eefe5eb2aaf42c00724f.jpg',
#  '5be86e35f21b1514d0e7742893d6cfba.jpg',
#  '5c0fe2919e49f30aff91d46800cdf149.jpg',
#  '5cd3d274d71e1e0d6bf075421461b2d5.jpg',
#  '5e84d36ad6db970548498829db8b15de.jpg',
#  '6057d1b6682ab473a3fe2ca8b4577259.jpg',
#  '614dbfa2f42c4684c0bb6152091113a6.jpg',
#  '6325b6870c54cd47be6ebfbffa620ec7.jpg',
#  '63523a600ab69f276664d0eade9d076e.jpg',
#  '64247967cbf6cd8bb2e243ac53aa5928.jpg',
#  '697ad1d2e45c1af54cab7847cbe324d8.jpg',
#  '6acca991d2353781779b866e4f96edd9.jpg',
#  '6bc04b3ec1f8d4da2a00f8662f4fbed3.jpg',
#  '6c3768639e82ceaeab681e083b897672.jpg',
#  '6ed34e1ab886e8a702ec59dd66ba4dff.jpg',
#  '70461caa9038cfa34d109ea056d57f5a.jpg',
#  '705b90361aeda1849a728d80625a78a9.jpg',
#  '7091af252a785131c5a124fb90705fda.jpg',
#  '723e472f98180745980efe32411d30c6.jpg',
#  '7264f56639c8c54158b94ced769082c8.jpg',
#  '736191946aaeaa637a0865a42c18b580.jpg',
#  '78fcb634d9838127464d827234ab05ad.jpg',
#  '797d10fe966b3aa35933669c3425525b.jpg',
#  '79e6b64a09ec7d393be193430ea732fe.jpg',
#  '7c4c57dda1b2e50f40b331cc8f9d233b.jpg',
#  '7e11aaffb1d08f8091ea94598f7865aa.jpg',
#  '7e3d8e737aec8f1eca019302593c732e.jpg',
#  '7e4c1d31e279a700c6b8e66d820e8601.jpg',
#  '7e6ae1b372e8e0b509b83ba3658b8107.jpg',
#  '7ee2e665b7de2e1cc29e3c65bde0c318.jpg',
#  '82fbc93cd45ab747e7e606f2c52c7335.jpg',
#  '8507eb0ef32c1c0db700f20aad6d9bcd.jpg',
#  '86089ddd9f9e52127ce838f210f776d7.jpg',
#  '88650de379b6ecb085ecb3c2e6b42d4c.jpg',
#  '8932c9a89b487bf9f2b3fce06c7c6553.jpg',
#  '89b95537d8697203ab278237289a52a8.jpg',
#  '8c6942026d53b881d1da9359ea19c9fc.jpg',
#  '8e961e4fd248c9496ca54808d2d2b25f.jpg',
#  '8ed6faebe087745cc1a3ed5aec2a57cf.jpg',
#  '90453db0386931707b256dfa1e32c404.jpg',
#  '90e56526f4c5892beac49f262b85150a.jpg',
#  '920154acbe49d3202ed7d2ed2df1ea13.jpg',
#  '955abcd11312fce2fd02a91a9b05ae71.jpg',
#  '964648862f322b2cc153239af04b22ef.jpg',
#  '968a2b3be84193e3f755c2fe71033a2c.jpg',
#  '998a39dca0ef610c3a0ea4e9cc6e1681.jpg',
#  '99b5905a1079edc2744b06a4049719e0.jpg',
#  '9a3cdc88ebbba7612e88eac1b82c5f82.jpg',
#  '9d279c825ba12804c337f883b366a6e2.jpg',
#  '9d2d833bf63095902417c2a35f72432a.jpg',
#  '9ec6285cc619688d787d641cb87c10d6.jpg',
#  '9f141b3c3d9096f5a897d01b48e3b360.jpg',
#  '9fb8662af03c957ade34d4c816d4e903.jpg',
#  'a060b5acc6e3fb814769805db61f589b.jpg',
#  'a11773bc4188f1c6226b941ec61c2024.jpg',
#  'a124d6e4c30b00918c594289266a383c.jpg',
#  'a1a266a37d38f7ce41d11f1868d8c9bf.jpg',
#  'a341f915962ee99754e962520f279708.jpg',
#  'a41371b2f8859b015031f0d5eda5184c.jpg',
#  'a445d1f73be8f81dd902fd5dc8529416.jpg',
#  'a6c820b76bc29bbe2d85eecad3de03f8.jpg',
#  'a76bf8400b3dbcdbe5a5678f4a8ea0f6.jpg',
#  'a7a294ddbcd9bbbc46c034079529c17c.jpg',
#  'a7bd63ef1d3b345d7f9a162865bb7c0d.jpg',
#  'a97b85d31d715c65b2970c4177eb0fda.jpg',
#  'a9b35b94610a3d7f4fa91f19693c5248.jpg',
#  'b33d82c619bf88c3e3bb8f53beab0c4b.jpg',
#  'b42a9b597a3a3dc8f428e2e2323e9aff.jpg',
#  'b4ccd4c315d99edd7c00d015b714485a.jpg',
#  'b78586222de9a1095d0a9d88455ee75f.jpg',
#  'beaa6285a2b9c66db0e294767711ca3f.jpg',
#  'c1e9b5875e442203073211c522072973.jpg',
#  'c36ea960a14f164ee0f39ad6beb3796a.jpg',
#  'c3c23b5aa5e388e5f71883f61d1a0561.jpg',
#  'c44a5dc5b5ebe5b3e0535b7c2b7921e4.jpg',
#  'd0fee79693c7dc3132d30491323b6407.jpg',
#  'd4684dcdc759dd9cdf41504698d737d8.jpg',
#  'd47f1cb78db4a23e2516e2d34da34c8a.jpg',
#  'd627a270302d23eef773d05ad01fd03c.jpg',
#  'daf06eb2b9613900299539558e287701.jpg',
#  'dbca6ab4ebf827884073e2890388b744.jpg',
#  'dd5d6f0649f40d49791bbd5c00758e2f.jpg',
#  'dde89969aecfa2c5245e8059c660b139.jpg',
#  'de911421573d3e234450040374b55b38.jpg',
#  'e40e9b4ae48e452dc407d299b467d0c3.jpg',
#  'e426290a8f57e82680275bb91df91ad1.jpg',
#  'e488005c7fb68747d3458c7d73760bae.jpg',
#  'e80e5151787eb21b0cca0d7dc3b0c338.jpg',
#  'e86daf9ebcdfc5c5dd088cdb7f8f8db6.jpg',
#  'e87bad0de3447c9ac3a8555e89545c75.jpg',
#  'e8ee7868b0c3d1d04b482cd4f3ec5ccc.jpg',
#  'e921fc17a0ed9a58f76d38558deb9337.jpg',
#  'e9420e9483f16db81c64dddf99f34841.jpg',
#  'ea16e13a7cf16d8665d1bc44738dfa88.jpg',
#  'ea199e645da893f2ab0c45cf07face13.jpg',
#  'ead122f4b1da293eb2d719baf104dfc9.jpg',
#  'eeecf5d16fa6591290706f1fd0c6fc6e.jpg',
#  'f4d4c2eec77732f56e47722d7a355f2b.jpg',
#  'f54d0c5cbd8e2270742293edf9075cb1.jpg',
#  'f74e1afad2c545c25ee38193d0eb87d5.jpg',
#  'f9a8320c182841024f47ebcba284085a.jpg',
#  'fa6f5eb34be4ad5daec225bfe09f2414.jpg',
#  'fb435889d257c924c7bf77396a555e04.jpg',
#  'fc009e0b404034e5ea065ba980917f33.jpg',
#  'fc3eb6ffed257270c26943e9f9c347b9.jpg',
#  'fda0890dba67c93a7c80b0993651caec.jpg']

# %%
df_test = df[df['image'].isin(all_test_files)]
df_test.shape
# Out:
# (158, 18)

# %%
df_comp = pd.DataFrame(columns=["uniq_id", "category", "predicted"])
for uniq_id, category in df_test.loc[:, ["uniq_id", "category0"]].values:
    my_image = tf.keras.preprocessing.image.load_img(f'C:/Users/pouri/OneDrive/Bureau/P6/7categ1/test/{sanitize_filename(category)}/{uniq_id}.jpg', target_size=(224, 224))
    my_image = tf.keras.preprocessing.image.img_to_array(my_image)
    my_image = my_image.reshape((1, my_image.shape[0], my_image.shape[1], my_image.shape[2]))
    prediction = model.predict(my_image, verbose=0)
    predicted = dataset_test.class_names[prediction.argmax(axis=-1)[0]]
    df_comp = pd.concat([df_comp, pd.DataFrame({"uniq_id": uniq_id, "category": category, "predicted": predicted}, index=[0])]).reset_index(drop=True)

# %%
df_comp['predicted'] = df_comp['predicted'].str.lower()

# %%
df_comp
# Out:
#                               uniq_id          category         predicted
# 0    d4684dcdc759dd9cdf41504698d737d8   home furnishing   home furnishing
# 1    6325b6870c54cd47be6ebfbffa620ec7   home furnishing   home furnishing
# 2    41384da51732c0b4df3de8f395714fbb           watches           watches
# 3    920154acbe49d3202ed7d2ed2df1ea13           watches           watches
# 4    3c74db45cbfc14a78b8466dca494b3bb           watches           watches
# ..                                ...               ...               ...
# 153  31ac1b66cc6bb396c83f124317589f8c         baby care         baby care
# 154  0c70a580d96e50966130e2885d8c3505  kitchen & dining  kitchen & dining
# 155  eeecf5d16fa6591290706f1fd0c6fc6e         computers         computers
# 156  6057d1b6682ab473a3fe2ca8b4577259         computers         computers
# 157  5a54c78b52c984e56500809e5bc27ae1         computers         computers
#
# [158 rows x 3 columns]

# %% [markdown]
# ## Matrice de confusion

# %%
conf_mat = confusion_matrix(df_comp["category"], df_comp["predicted"])
conf_mat
# Out:
# array([[12,  1,  1,  3,  2,  1,  2],
#        [ 0, 18,  0,  1,  2,  0,  1],
#        [ 1,  2, 19,  1,  0,  0,  0],
#        [ 2,  0,  1, 14,  3,  3,  0],
#        [ 3,  0,  0,  2, 17,  0,  0],
#        [ 2,  0,  2,  0,  1, 18,  0],
#        [ 1,  0,  1,  0,  0,  0, 21]], dtype=int64)

# %%
df_cm = pd.DataFrame(conf_mat, index = dataset_test.class_names,
                  columns = dataset_test.class_names)

plt.figure(figsize = (6,4))
sns.heatmap(df_cm, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# ## Score de classification

# %%
print(classification_report(df_comp["category"], df_comp["predicted"]))
# Out:
#                             precision    recall  f1-score   support
#
#                  baby care       0.57      0.55      0.56        22
#   beauty and personal care       0.86      0.82      0.84        22
#                  computers       0.79      0.83      0.81        23
# home decor & festive needs       0.67      0.61      0.64        23
#            home furnishing       0.68      0.77      0.72        22
#           kitchen & dining       0.82      0.78      0.80        23
#                    watches       0.88      0.91      0.89        23
#
#                   accuracy                           0.75       158
#                  macro avg       0.75      0.75      0.75       158
#               weighted avg       0.75      0.75      0.75       158

# %% [markdown]
# Nous avons ici un score F1 global de 75%.

# %% [markdown]
# ## Analyse des erreurs
#
# La catégorie de produits qui a donné le plus grand taux de faux négatifs est "baby care". Visualisons les images correspondantes.

# %%
df_comp.loc[(df_comp["category"]=="baby care") & (df_comp["predicted"]!="baby care")]
# Out:
#                               uniq_id   category                   predicted
# 19   184ecf07ca4e2872eaf53d2344a1e783  baby care            kitchen & dining
# 60   70461caa9038cfa34d109ea056d57f5a  baby care                   computers
# 61   dd5d6f0649f40d49791bbd5c00758e2f  baby care                     watches
# 88   705b90361aeda1849a728d80625a78a9  baby care  home decor & festive needs
# 92   f9a8320c182841024f47ebcba284085a  baby care  home decor & festive needs
# 93   d0fee79693c7dc3132d30491323b6407  baby care             home furnishing
# 115  fb435889d257c924c7bf77396a555e04  baby care    beauty and personal care
# 139  a445d1f73be8f81dd902fd5dc8529416  baby care                     watches
# 147  d627a270302d23eef773d05ad01fd03c  baby care             home furnishing
# 148  c44a5dc5b5ebe5b3e0535b7c2b7921e4  baby care  home decor & festive needs

# %%
for uniq_id, category, predicted in df_comp.loc[(df_comp["category"]=="beauty and personal care") & (df_comp["predicted"]!="beauty and personal care"), ["uniq_id", "category", "predicted"]].values:
    print(f"""{uniq_id} : Prédit "{predicted}" au lieu de "{category}" """)
    img = plt.imread(f'C:/Users/pouri/OneDrive/Bureau/P6/7categ1/test/{sanitize_filename(category)}/{uniq_id}.jpg')
    imgplot = plt.imshow(img)
    plt.show()
# Out:
# 24e85c590481a7cedfe66597f253f2b2 : Prédit "watches" au lieu de "beauty and personal care"
# 1971dcd2f3058a4c87bdd7d87d4baeba : Prédit "home furnishing" au lieu de "beauty and personal care"
# 5749bae8ccead7997ebf370b6b081d07 : Prédit "home furnishing" au lieu de "beauty and personal care"
# a11773bc4188f1c6226b941ec61c2024 : Prédit "home decor & festive needs" au lieu de "beauty and personal care"

# %%
for uniq_id, category, predicted in df_comp.loc[(df_comp["category"]=="computers") & (df_comp["predicted"]!="computers"), ["uniq_id", "category", "predicted"]].values:
    print(f"""{uniq_id} : Prédit "{predicted}" au lieu de "{category}" """)
    img = plt.imread(f'C:/Users/pouri/OneDrive/Bureau/P6/7categ1/test/{sanitize_filename(category)}/{uniq_id}.jpg')
    imgplot = plt.imshow(img)
    plt.show()
# Out:
# e8ee7868b0c3d1d04b482cd4f3ec5ccc : Prédit "beauty and personal care" au lieu de "computers"
# 00e966a5049a262cfc72e6bbf68b80e7 : Prédit "baby care" au lieu de "computers"
# 8e961e4fd248c9496ca54808d2d2b25f : Prédit "beauty and personal care" au lieu de "computers"
# 568f331e1039bf2e0635b899c2b3248f : Prédit "home decor & festive needs" au lieu de "computers"
